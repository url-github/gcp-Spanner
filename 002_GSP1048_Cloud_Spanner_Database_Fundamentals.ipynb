# %% [markdown]
# [Cloud Spanner - Database Fundamentals](https://www.cloudskillsboost.google/focuses/54352?catalog_rank=%7B%22rank%22%3A3%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23642501)

# %% [markdown]
# ![2023-05-03 17_36_13-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_37_38-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# banking-instance

# %% [markdown]
# ![2023-05-03 17_44_48-Spanner – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_45_23-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_46_21-Create a database in banking-instance – Spanner – qwiklabs-gcp-03-86c… – Google .png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_47_33-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/spanner/docs/reference/standard-sql/data-definition-language

# %%
CREATE TABLE Customer (
  CustomerId STRING(36) NOT NULL,
  Name STRING(MAX) NOT NULL,
  Location STRING(MAX) NOT NULL,
) PRIMARY KEY (CustomerId);

# %% [markdown]
# ![2023-05-03 17_51_07-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_51_25-Customer – Schema – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_52_12-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
INSERT INTO
  Customer (CustomerId,
    Name,
    Location)
VALUES
  ('bdaaaa97-1b4b-4e58-b4ad-84030de92235',
    'Richard Nelson',
    'Ada Ohio'
    );

# %% [markdown]
# ![2023-05-03 17_54_33-Customer – Query – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_54_53-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
INSERT INTO
  Customer (CustomerId,
    Name,
    Location)
VALUES
  ('b2b4002d-7813-4551-b83b-366ef95f9273',
    'Shana Underwood',
    'Ely Iowa'
    );

# %% [markdown]
# ![2023-05-03 17_56_15-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_57_04-Customer – Data – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %%
SELECT * FROM Customer;

# %% [markdown]
# ![2023-05-03 17_57_37-Customer – Query – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_57_56-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 17_58_14-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
 gcloud spanner instances create [INSTANCE-ID] \
    --config=[INSTANCE-CONFIG] \
    --description="[INSTANCE-NAME]" \
    --nodes=[NODE-COUNT]

# %% [markdown]
# ![2023-05-03 17_59_26-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances create banking-instance-2 \
--config=regional-us-central1  \
--description="Banking Instance 2" \
--nodes=2

# %% [markdown]
# ![2023-05-03 18_00_41-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_00_58-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances list

# %% [markdown]
# ![2023-05-03 18_01_41-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_02_31-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner databases create banking-db-2 --instance=banking-instance-2

# %% [markdown]
# ![2023-05-03 18_03_18-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_03_47-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances update banking-instance-2 --nodes=1

# %% [markdown]
# ![2023-05-03 18_05_11-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_05_30-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances list

# %% [markdown]
# ![2023-05-03 18_06_01-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_06_29-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/docs/terraform

# %% [markdown]
# ![2023-05-03 18_07_34-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_08_29-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_08_01-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_08_47-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
nano spanner.tf

# %% [markdown]
# ![2023-05-03 18_09_21-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
resource "google_spanner_instance" "banking-instance-3" {
  name         = "banking-instance-3"
  config       = "regional-us-central1"
  display_name = "Banking Instance 3"
  num_nodes    = 2
  labels = {
  }
}

# %% [markdown]
# ![2023-05-03 18_11_03-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
terraform init

# %% [markdown]
# ![2023-05-03 18_11_52-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_12_30-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
terraform plan

# %% [markdown]
# ![2023-05-03 18_13_06-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_13_36-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
terraform apply

# %% [markdown]
# ![2023-05-03 18_14_35-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_15_19-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 18_17_46-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances list

# %% [markdown]
# ![2023-05-03 18_18_07-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances delete banking-instance-2

# %% [markdown]
# ![2023-05-03 18_18_52-Cloud Spanner — podstawy bazy danych _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud spanner instances list

# %% [markdown]
# ![2023-05-03 18_19_26-Instances – qwiklabs-gcp-03-86c… – Google Cloud console.png](data:image/png;base64,...)
