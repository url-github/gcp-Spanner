# %% [markdown]
# [Cloud Spanner: Qwik Start](https://www.cloudskillsboost.google/focuses/1774?catalog_rank=%7B%22rank%22%3A2%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23641798)

# %% [markdown]
# ![2023-05-03 15_04_32-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/products/storage

# https://cloud.google.com/products/databases#store

# %% [markdown]
# ![2023-05-03 15_22_23-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_30_56-Spanner – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 15_23_10-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_31_55-Create a database in Test Instance – Spanner – qwiklabs-gcp-03-9e8… – Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 15_24_06-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_33_07-example-db – Overview – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %%
CREATE TABLE Singers (
  SingerId   INT64 NOT NULL,
  FirstName  STRING(1024),
  LastName   STRING(1024),
  SingerInfo BYTES(MAX),
  BirthDate  DATE,
) PRIMARY KEY(SingerId);

# %% [markdown]
# ![2023-05-03 16_33_52-Write DDL statements – Spanner – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 15_24_36-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 15_25_25-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_35_19-Singers – Schema – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_18_52-Cloud Spanner_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
INSERT INTO
  Singers (SingerId,
    FirstName,
    LastName,
    SingerInfo,
    BirthDate)
VALUES
  (1, -- type: INT64
    'Marc', -- type: STRING(1024)
    'Richards', -- type: STRING(1024)
    NULL, -- type: BYTES(MAX)
    NULL -- type: DATE
    )
THEN RETURN
  SingerId,
  FirstName,
  LastName,
  SingerInfo,
  BirthDate;

# %% [markdown]
# ![2023-05-03 16_39_19-Singers – Query – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_40_46-Singers – Query – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_41_35-Singers – Data – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_20_20-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_46_07-Cloud Spanner_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
INSERT INTO
  Singers (SingerId,
    FirstName,
    LastName,
    SingerInfo,
    BirthDate)
VALUES
  (2, -- type: INT64
    'Catalina', -- type: STRING(1024)
    'Smith', -- type: STRING(1024)
    NULL, -- type: BYTES(MAX)
    NULL -- type: DATE
    )
THEN RETURN
  SingerId,
  FirstName,
  LastName,
  SingerInfo,
  BirthDate;

# %% [markdown]
# ![2023-05-03 16_47_13-Singers – Query – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_21_38-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_23_21-Cloud Spanner_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
INSERT INTO
  Singers (SingerId,
    FirstName,
    LastName,
    SingerInfo,
    BirthDate)
VALUES
  (3, -- type: INT64
    'Kena', -- type: STRING(1024)
    '', -- type: STRING(1024)
    NULL, -- type: BYTES(MAX)
    NULL -- type: DATE
    )
THEN RETURN
  SingerId,
  FirstName,
  LastName,
  SingerInfo,
  BirthDate;

# %% [markdown]
# ![2023-05-03 16_24_10-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_48_03-Singers – Data – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_24_34-Cloud Spanner_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# Change values in the SET clause to update the row where the WHERE condition is true.
UPDATE
  Singers
SET
  FirstName='Kena',
  LastName='',
  SingerInfo=NULL,
  BirthDate='1961-04-01'
WHERE
  SingerId=3
THEN RETURN
  SingerId,
  FirstName,
  LastName,
  SingerInfo,
  BirthDate;

# %% [markdown]
# ![2023-05-03 16_25_09-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_52_19-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-03 16_55_47-Cloud Spanner_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
SELECT * FROM Singers

# %% [markdown]
# ![2023-05-03 16_57_17-example-db – Query – qwiklabs-gcp-03-9e8… – Google Cloud console.png](data:image/png;base64,...)
